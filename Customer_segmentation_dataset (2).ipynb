# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Anantram\\Downloads\\customer_segmentation_dataset.csv")

# %%
print(df)
# Out:
#     Customer_ID        Customer_Name  Age  Gender       City  Annual_Income  \
# 0       CUST001  Mrs. Gail Kelly PhD   58  Female  Bangalore          34592
# 1       CUST002        Donald Brooks   65    Male      Delhi          33434
# 2       CUST003        Taylor Rogers   19    Male      Delhi          32280
# 3       CUST004          Beth Walker   32    Male  Bangalore          78878
# 4       CUST005    Stephanie Schmidt   35  Female  Hyderabad          40379
# ..          ...                  ...  ...     ...        ...            ...
# 195     CUST196          Ann Simmons   18    Male    Chennai          46794
# 196     CUST197         Ricky Oliver   25  Female  Bangalore          21013
# 197     CUST198       Donna Anderson   52  Female  Hyderabad         112231
# 198     CUST199        Michael Tapia   45  Female      Delhi          22456
# 199     CUST200        Kyle Williams   63    Male     Mumbai         103904
#
# ...

# %%
print(df.head())
# Out:
#   Customer_ID        Customer_Name  Age  Gender       City  Annual_Income  \
# 0     CUST001  Mrs. Gail Kelly PhD   58  Female  Bangalore          34592
# 1     CUST002        Donald Brooks   65    Male      Delhi          33434
# 2     CUST003        Taylor Rogers   19    Male      Delhi          32280
# 3     CUST004          Beth Walker   32    Male  Bangalore          78878
# 4     CUST005    Stephanie Schmidt   35  Female  Hyderabad          40379
#
#    Spending_Score  Purchase_Frequency Preferred_Category Online_Shopping
# 0               4                  48            Fashion             Yes
# 1              87                  48             Beauty             Yes
# 2              28                  15            Fashion              No
# 3              76                  18             Beauty              No
# 4              28                  49        Electronics              No

# %%
print(df.shape)
# Out:
# (200, 10)

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of     Customer_ID        Customer_Name  Age  Gender       City  Annual_Income  \
# 0       CUST001  Mrs. Gail Kelly PhD   58  Female  Bangalore          34592
# 1       CUST002        Donald Brooks   65    Male      Delhi          33434
# 2       CUST003        Taylor Rogers   19    Male      Delhi          32280
# 3       CUST004          Beth Walker   32    Male  Bangalore          78878
# 4       CUST005    Stephanie Schmidt   35  Female  Hyderabad          40379
# ..          ...                  ...  ...     ...        ...            ...
# 195     CUST196          Ann Simmons   18    Male    Chennai          46794
# 196     CUST197         Ricky Oliver   25  Female  Bangalore          21013
# 197     CUST198       Donna Anderson   52  Female  Hyderabad         112231
# 198     CUST199        Michael Tapia   45  Female      Delhi          22456
# 199     CUST200        Kyle Williams   63    Male     Mumbai         103904
#
# ...

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of     Customer_ID        Customer_Name  Age  Gender       City  Annual_Income  \
# 0       CUST001  Mrs. Gail Kelly PhD   58  Female  Bangalore          34592
# 1       CUST002        Donald Brooks   65    Male      Delhi          33434
# 2       CUST003        Taylor Rogers   19    Male      Delhi          32280
# 3       CUST004          Beth Walker   32    Male  Bangalore          78878
# 4       CUST005    Stephanie Schmidt   35  Female  Hyderabad          40379
# ..          ...                  ...  ...     ...        ...            ...
# 195     CUST196          Ann Simmons   18    Male    Chennai          46794
# 196     CUST197         Ricky Oliver   25  Female  Bangalore          21013
# 197     CUST198       Donna Anderson   52  Female  Hyderabad         112231
# 198     CUST199        Michael Tapia   45  Female      Delhi          22456
# 199     CUST200        Kyle Williams   63    Male     Mumbai         103904
#
# ...

# %%
print(df.drop_duplicates(inplace=True))
# Out:
# None

# %%
data=df[["Annual_Income","Spending_Score","Purchase_Frequency"]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
print(scaled_data)
# Out:
# [[-1.35959834e+00 -1.79627558e+00  1.54253333e+00]
#  [-1.39008488e+00  1.25105959e+00  1.54253333e+00]
#  [-1.42046612e+00 -9.15118425e-01 -7.66019952e-01]
#  [-1.93685398e-01  8.47195894e-01 -5.56151472e-01]
#  [-1.20724459e+00 -9.15118425e-01  1.61248949e+00]
#  [-5.05027276e-01 -2.90965437e-01  9.12927888e-01]
#  [-1.47185622e+00  6.63621486e-01 -4.86195312e-01]
#  [ 5.38070690e-01 -8.41688661e-01  1.68244565e+00]
#  [-7.84566263e-01  2.23042906e-01  1.05284021e+00]
#  [ 5.68820505e-01 -6.58114253e-01  1.33266485e+00]
#  [-1.48640078e-01 -1.44105910e-01 -5.56151472e-01]
#  [ 1.03420105e+00 -4.37824964e-01  3.49780800e-03]
#  [ 5.17956941e-01  4.06617314e-01  3.49780800e-03]
#  [ 8.26982052e-01  7.00336367e-01  6.33103248e-01]
#  [-9.86967443e-01 -1.28226724e+00  4.93190928e-01]
#  [ 4.21363558e-01 -1.17212260e+00  1.26270869e+00]
#  [ 3.12475514e-01  2.59757788e-01  5.63147088e-01]
#  [ 1.30936978e+00  5.90191722e-01  1.61248949e+00]
# ...

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss,marker='o')
plt.xlabel("Number of Clusters")
plt.ylabel("wcss")
plt.title("Leg Method")
plt.show()

# %%
Kmeans= KMeans(n_clusters=5,random_state=42)

df["Cluster"] = kmeans.fit_predict(scaled_data)
print(df["Cluster"])
# Out:
# 0      5
# 1      4
# 2      7
# 3      6
# 4      5
#       ..
# 195    7
# 196    4
# 197    2
# 198    1
# 199    9
# Name: Cluster, Length: 200, dtype: int32

# %%
plt.scatter(df["Annual_Income"], df["Spending_Score"], c=df["Cluster"])

plt.xlabel("Annual_Income")
plt.ylabel("Spending Score")
plt.title("Customer segments")

plt.show()

# %%
cluster_analysis = df.groupby("Cluster").mean(numeric_only=True)
print(cluster_analysis)
# Out:
#                Age  Annual_Income  Spending_Score  Purchase_Frequency
# Cluster
# 0        50.285714  129390.000000       74.476190           40.666667
# 1        42.956522   50575.217391       67.173913           11.521739
# 2        42.148148  114830.777778       26.074074           36.777778
# 3        36.705882  114867.882353       27.588235           10.176471
# 4        41.944444   45214.000000       77.555556           38.944444
# 5        41.454545   51349.636364       19.636364           46.545455
# 6        40.000000   83439.478261       82.086957           24.956522
# 7        39.785714   49374.785714       22.000000           12.000000
# 8        40.000000   47610.166667       30.611111           32.944444
# 9        43.392857  123833.821429       69.428571           12.750000

# %% [markdown]
# Final Insights
#
# ## Business Insights
#
# - Premium customers spend more on fashion and electronics.
#
# - Young customers shop online frequently.
#
# - Customers with low spending scores may respond well to discount offers and marketing campaigns.
#
# - High income customers tend to purchase more premium products.
#
# - Frequent buyers can be targeted with loyalty programs.

# %%
df.to_excel("Customer_segmenatation_dataset.xlsx", index=False)
